# %%
from dataloader import load_data
from plotting import plot_umap, plot_cosine_similarity_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S2')

# %%
plot_umap(data_dict, experiment='fine-tuning', model='fine-tuned')

# %%
plot_umap(data_dict, experiment='fine-tuning', model='pre-trained')

# %%
plot_cosine_similarity_matrix(data_dict['pre-trained'])
