# %%
from dataloader import load_data
from plotting import plot_cross_validated_outlier_score

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S10')

# %%
for moa in ['Cell wall (PBP)', 'Gyrase', 'RNA polymerase', 'Ribosome']:
    plot_cross_validated_outlier_score(data_dict, moa=moa)
