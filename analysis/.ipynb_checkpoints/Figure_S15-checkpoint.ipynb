# %%
from dataloader import load_data
from plotting import plot_adjacency_graph

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S15')

# %%
plot_adjacency_graph(data_dict, model='hand-crafted')
