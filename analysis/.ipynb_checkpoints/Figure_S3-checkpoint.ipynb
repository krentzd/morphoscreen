# %%
from dataloader import load_data
from plotting import plot_cell_densities, plot_accuracies

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S3')

# %%
for t in [6, 16]:
    plot_cell_densities(data_dict, t=t)

# %%
plot_accuracies(data_dict)
