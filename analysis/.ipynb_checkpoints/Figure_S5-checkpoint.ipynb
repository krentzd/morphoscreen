# %%
from dataloader import load_data
from plotting import plot_cnn_vs_rf_benchmark, plot_rf_preds

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S5')

# %%
plot_cnn_vs_rf_benchmark(data_dict)
# Out:
# RF accuracy: 0.7246376811594203 +/- 0.08574028671158866
# CNN accuracy: 0.927536231884058 +/- 0.089339333376362
# p=0.03125

# %%
plot_rf_preds(data_dict)
