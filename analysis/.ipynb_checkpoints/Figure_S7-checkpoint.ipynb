# %%
from dataloader import load_data
from plotting import plot_umap_trajectories, plot_preds_by_concentration

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S7')

# %%
plot_umap_trajectories(data_dict)

# %%
plot_preds_by_concentration(data_dict)
