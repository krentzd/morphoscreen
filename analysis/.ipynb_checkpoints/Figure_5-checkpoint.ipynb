# %%
from dataloader import load_data
from plotting import plot_umap, plot_adjacency_graph

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig=5)

# %%
plot_umap(data_dict, experiment='cellcycle')

# %%
plot_adjacency_graph(data_dict)
