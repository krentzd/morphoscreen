# %%
from dataloader import load_data
from plotting import plot_cnn_preds, plot_outlier_score

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S9')

# %%
plot_cnn_preds(data_dict)

# %%
plot_outlier_score(data_dict)
