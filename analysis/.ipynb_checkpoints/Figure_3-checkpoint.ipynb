# %%
from dataloader import load_data
from plotting import plot_umap, plot_hierarchical_clustering

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig=3)

# %%
plot_umap(data_dict)

# %%
plot_hierarchical_clustering(data_dict)
