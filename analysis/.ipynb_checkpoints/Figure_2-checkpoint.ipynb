# %%
from dataloader import load_data
from plotting import plot_classification_accuracies, plot_confusion_matrix, plot_cosine_similarity_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig=2)

# %%
plot_classification_accuracies(data_dict)

# %%
plot_confusion_matrix(data_dict)

# %%
plot_cosine_similarity_matrix(data_dict)
