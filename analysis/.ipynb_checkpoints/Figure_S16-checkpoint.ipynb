# %%
from dataloader import load_data
from plotting import plot_confusion_matrix, plot_bf_vs_all_benchmark 

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S16')

# %%
plot_bf_vs_all_benchmark(data_dict)
# Out:
# BF accuracy: 0.7915942028985508 +/- 0.07247304288471366
# Hoechst FM4 BF accuracy: 0.8724637681159421 +/- 0.07265019497329402
# p=0.03125

# %%
plot_confusion_matrix(data_dict, cmpd_vs_moa=False)
