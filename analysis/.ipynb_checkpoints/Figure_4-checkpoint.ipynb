# %%
from dataloader import load_data
from plotting import plot_umap, plot_clustermap, plot_mlp_preds

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig=4)

# %%
plot_umap(data_dict, experiment='mutants-drugs')

# %%
plot_clustermap(data_dict)

# %%
plot_mlp_preds(data_dict)
