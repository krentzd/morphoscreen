# %%
from dataloader import load_data
from plotting import plot_rf_preds

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S13')

# %%
plot_rf_preds(data_dict, experiment='mutant-drugs')

# %%
plot_rf_preds(data_dict, experiment='mutant-drugs', by_pathway=True)
