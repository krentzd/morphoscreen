# %%
from dataloader import load_data
from plotting import plot_cross_validated_clustering_score

import warnings
warnings.filterwarnings('ignore')

# %%
data_dict = load_data(fig='S11')

# %%
for moa in ['Cell wall (PBP)', 'Gyrase', 'RNA polymerase', 'Ribosome']:
    plot_cross_validated_clustering_score(data_dict, moa=moa)
# Out:
# [0.92145 0.9795  0.98105]
# [0.9764  0.9634  0.99825]
# [0.90805 0.9726  0.99535]
# [0.7231  0.96455 0.98885]
